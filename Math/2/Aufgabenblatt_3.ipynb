# %% [markdown]
# # Aufgabenblatt 3

# %% [markdown]
# ## Eindimensionale Analysis – Differentialrechnung 3

# %% [markdown]
# ### Aufgabe 1
#
# Es sei $f(t)=\left( \begin{array}{c}
#  \sin{t} \\
#  \cos{t} \\
#  t
#   \end{array} \right)$. Plotten Sie die Funktion. Bestimmen Sie $\frac{df(t)}{dt},
#   \frac{d^2f(t)}{dt^2}, \|\frac{df(t)}{dt}\|,\|
#   \frac{d^2f(t)}{dt^2}\|$.

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.figure().add_subplot(projection = '3d')

t = np.linspace(0, 10*np.pi, 1000)
x = np.sin(t)
y = np.cos(t)
z = t

ax.plot(x, y, z)

ax.set_xlabel('X', fontweight = 'bold', fontsize = 14)
ax.set_ylabel('Y', fontweight = 'bold', fontsize = 14)
ax.set_zlabel('Z', fontweight = 'bold', fontsize = 14)

plt.title('Funktion f(t)', fontweight = 'bold', fontsize = 16)

plt.show()

# %% [markdown]
# $$\frac{df(t)}{dt}$$
# $$f'(t)=\left( \begin{array}{c}\cos{t} \\ -\sin{t} \\ 1  \end{array} \right)$$
#
#
# $$\frac{d^2f(t)}{dt^2}$$
# $$f''(t)=\left( \begin{array}{c}-\sin{t} \\ -\cos{t} \\ 0  \end{array} \right)$$
#
# $$\|\frac{df(t)}{dt}\| = \sqrt{\cos^2{t}+\sin^2{t}+1} = \sqrt{2}$$
# $$\|\frac{d^2f(t)}{dt^2}\| = \sqrt{\sin^2{t}+\cos^2{t}} = 1$$

# %% [markdown]
# ### Aufgabe 2
#
# Ein Teilchen bewegt sich auf einer Kurve mit der Parametergleichung
# $f(t)=\left(
# \begin{array}{c}
#  e^{-t} \\
#  2\cos{3t} \\
#  2\sin{3t}
#   \end{array} \right)$.

# %% [markdown]
# a) Bestimmen Sie die Geschwindigkeit und die Beschleunigung
# $$f'(t)=\left( \begin{array}{c}-e^{-t} \\ -6\sin{3t} \\ 6\cos{3t}  \end{array} \right) - Geschwindigkeit $$
# $$f''(t)=\left( \begin{array}{c}e^{-t} \\ -18\cos{3t} \\ -18\sin{3t}  \end{array} \right) - Beschleunigung $$

# %% [markdown]
# b) Geben Sie die Größe der Geschwindigkeit und der Beschleunigung für $t=0$ an.
# $$\|f'(t)\| = \sqrt{1+0+36}=\sqrt{37}$$
# $$\|f''(t)\| = \sqrt{1+0+324}=\sqrt{325}=5\sqrt{13}$$

# %% [markdown]
# ### Aufgabe 3
#
# Es sei folgende Raumkurve $\mathbf{R}$ gegeben (Schraubenlinie):
# $\mathbf{R}=\left(
# \begin{array}{c}
#  3\cos{t} \\
#  3\sin{t}\\
#  4t
#   \end{array} \right)$.
#
# Bestimmen Sie:
#
# a) die Einheitstangente (normiert auf die Bogenlänge $s$) $\mathbf{T}=\frac{d\mathbf{R}}{ds}=\frac{d\mathbf{R}/dt}
# {ds/dt}=\frac{d\mathbf{R}/dt} {\|d\mathbf{R}/dt\|}$
# $$\frac{d\mathbf{R}}{dt}=\left(\begin{array}{c} -3\sin{t} \\ 3\cos{t}\\ 4  \end{array} \right)$$
# $$\|\frac{d\mathbf{R}}{dt}\|=\sqrt{9\sin^2{t}+9\cos^2{t}+16}=\sqrt{9+16}=5$$
# $$\mathbf{T}=\left(\begin{array}{c} -\frac{3}{5}\sin{t} \\ \frac{3}{5}\cos{t}\\ \frac{4}{5}  \end{array} \right)$$

# %% [markdown]
# b) die Krümmung $\kappa=\|\frac{d\mathbf{T}}{ds}\|$
# $$\kappa=\|\frac{d\mathbf{T}/dt}{ds/dt}\|=\|\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}\|$$
# $$\frac{d\mathbf{T}}{dt}=\left(\begin{array}{c} -\frac{3}{5}\cos{t} \\ -\frac{3}{5}\sin{t}\\ 0  \end{array} \right)$$
# $$\|\frac{d\mathbf{T}}{dt}\|=\sqrt{(-\frac{3}{5}\cos{t})^2 + (-\frac{3}{5}\sin{t})^2 +0} =\frac{3}{5}$$
# $$\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}=\left(\begin{array}{c} -\cos{t} \\ -\sin{t}\\ 0  \end{array} \right)$$
# $$\|\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}\|=\sqrt{\cos^2{t}+\sin^2{t}}=1$$

# %% [markdown]
# c) die Hauptnormale $\mathbf{N}=\frac{1}{\kappa}\frac{d\mathbf{T}}{ds}$
# $$\mathbf{N}=(\frac{d\mathbf{T}}{ds})/\|\frac{d\mathbf{T}}{ds}\|=\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}=\left(\begin{array}{c} -\cos{t} \\ -\sin{t}\\ 0  \end{array} \right)$$

# %% [markdown]
# ### Aufgabe 4
#
# Bestimmen Sie in Fortsetzung der vorangegangenen Aufgabe:
#
# a) die Binormale $\mathbf{B}=\mathbf{T}\times\mathbf{N}$
# $$\mathbf{B} = \left(\begin{array}{c} -\frac{3}{5}\sin{t} \\ \frac{3}{5}\cos{t}\\ \frac{4}{5}  \end{array} \right)\times\left(\begin{array}{c} -\cos{t} \\ -\sin{t}\\ 0  \end{array} \right)=\left(\begin{array}{c} \frac{3}{5}\cos{t}*0-\frac{4}{5}*(-\sin{t}) \\ \frac{4}{5}*(-\cos{t})-(-\frac{3}{5}\sin{t}*0)\\ -\frac{3}{5}\sin{t}*(-\sin{t})-\frac{3}{5}\cos{t}*(-\cos{t})  \end{array} \right)=\left(\begin{array}{c} -\frac{4}{5}\sin{t} \\ -\frac{4}{5}\cos{t}\\ \frac{3}{5}  \end{array} \right)$$

# %% [markdown]
# b) die Torsion $\tau$, diese ergibt sich aus $\frac{d\mathbf{B}}{ds}=-\tau\mathbf{N} => \tau=-\mathbf{N}*\frac{d\mathbf{B}}{ds}$
# $$\frac{d\mathbf{B}}{ds}=\frac{d\mathbf{B}/dt} {\|d\mathbf{B}/dt\|}$$
# $$\frac{d\mathbf{B}}{dt} = \left(\begin{array}{c} -\frac{4}{5}\cos{t} \\ \frac{4}{5}\sin{t}\\ 0  \end{array} \right)$$
# $$\|d\mathbf{B}/dt\|=\sqrt{(-\frac{4}{5}\cos{t})^2+(\frac{4}{5}\sin{t})^2}=\frac{4}{5}$$
# $$\frac{d\mathbf{B}/dt} {\|d\mathbf{B}/dt\|} = \left(\begin{array}{c} -\cos{t} \\ \sin{t}\\ 0  \end{array} \right)$$
# $$\tau = \left(\begin{array}{c} \cos{t} \\ \sin{t}\\ 0  \end{array} \right)*\left(\begin{array}{c} -\cos{t} \\ \sin{t}\\ 0  \end{array} \right) = -\cos^2{t}+\sin^2{t}=-\cos{2t}$$

# %% [markdown]
# ### Aufgabe 5
#
# Es sei folgende Raumkurve $\mathbf{R}$ gegeben:
# $\mathbf{R}=\left(
# \begin{array}{c}
#  t \\
#  t^2\\
#  \frac{2}{3}t^3
#   \end{array} \right)$.
#
# Bestimmen Sie die Einheitstangente $\mathbf{T}$ (normiert auf die Bogenlänge $s$).

# %% [markdown]
# $\mathbf{T}=\frac{d\mathbf{R}}{ds}=\frac{d\mathbf{R}/dt}
# {ds/dt}=\frac{d\mathbf{R}/dt} {\|d\mathbf{R}/dt\|}$
# $$\frac{d\mathbf{R}}{dt}=\left(\begin{array}{c} 1 \\ 2t \\ 2t^2  \end{array} \right)$$
# $$\|\frac{d\mathbf{R}}{dt}\|=\sqrt{1+4t^2+4t^4}=\sqrt{(1+2t^2)^2}=1+2t^2$$
# $$\mathbf{T}=\left(\begin{array}{c} \frac{1}{1+2t^2} \\ \frac{2t}{1+2t^2} \\ \frac{2t^2}{1+2t^2}  \end{array} \right)$$

# %% [markdown]
# ### Aufgabe 6
#
#
# Bestimmen Sie in Fortsetzung der vorangegangenen Aufgabe die Krümmung $\kappa$ sowie die Hauptnormale $\mathbf{N}$.

# %% [markdown]
# die Krümmung $\kappa=\|\frac{d\mathbf{T}}{ds}\|$
# $$\kappa=\|\frac{d\mathbf{T}/dt}{ds/dt}\|=\|\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}\|$$
# $$\frac{d\mathbf{T}}{dt}=\left(\begin{array}{c} -\frac{4t}{(1+2t^2)^2} \\ \frac{2-4t^2}{(1+2t^2)^2}\\ \frac{4t^2}{(1+2t^2)^2}  \end{array} \right)$$
# $$\|\frac{d\mathbf{T}}{dt}\|=\sqrt{(-\frac{4t}{(1+2t^2)^2})^2 + (\frac{2-4t^2}{(1+2t^2)^2})^2 +(\frac{4t^2}{(1+2t^2)^2})^2} =\frac{2\sqrt{1+8t^4}}{(1+2t^2)^2}$$
# $$\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}=\left(\begin{array}{c} (-\frac{4t}{(1+2t^2)^2)})*\frac{(1+2t^2)^2}{2\sqrt{1+8t^4}} \\ \frac{2-4t^2}{(1+2t^2)^2}*\frac{(1+2t^2)^2}{2\sqrt{1+8t^4}}\\ \frac{4t^2}{(1+2t^2)^2}*\frac{(1+2t^2)^2}{2\sqrt{1+8t^4}}  \end{array} \right) = \left(\begin{array}{c} -\frac{2t}{\sqrt{1+8t^4}} \\ \frac{1-2t^2}{\sqrt{1+8t^4}}\\ \frac{2t^2}{\sqrt{1+8t^4}}  \end{array} \right)$$
# $$\kappa=\sqrt{(-\frac{2t}{\sqrt{1+8t^4}})^2+(\frac{1-2t^2}{\sqrt{1+8t^4}})^2+(\frac{2t^2}{\sqrt{1+8t^4}})^2}=1$$
# $$\mathbf{N}=\frac{1}{\kappa}\frac{d\mathbf{T}}{ds}$$
# $$\mathbf{N}=(\frac{d\mathbf{T}}{ds})/\|\frac{d\mathbf{T}}{ds}\|=\frac{d\mathbf{T}/dt}{\|d\mathbf{T}/dt\|}=\left(\begin{array}{c} -\frac{2t}{\sqrt{1+8t^4}} \\ \frac{1-2t^2}{\sqrt{1+8t^4}}\\ \frac{2t^2}{\sqrt{1+8t^4}}  \end{array} \right)$$

# %% [markdown]
# ### Aufgabe 7
#
# Bestimmen Sie in Fortsetzung der vorangegangenen Aufgabe die Binormale $\mathbf{B}$.

# %% [markdown]
# die Binormale $\mathbf{B}=\mathbf{T}\times\mathbf{N}$
# $$\mathbf{B} = \left(\begin{array}{c} \frac{1}{1+2t^2} \\ \frac{2t}{1+2t^2} \\ \frac{2t^2}{1+2t^2}  \end{array} \right)\times\left(\begin{array}{c} -\frac{2t}{\sqrt{1+8t^4}} \\ \frac{1-2t^2}{\sqrt{1+8t^4}}\\ \frac{2t^2}{\sqrt{1+8t^4}}  \end{array} \right)$$

# %% [markdown]
# $$\mathbf{B} = \left(\begin{array}{c}
# \frac{1}{1+2t^2}
# \\
# \frac{2t}{1+2t^2}
# \\
# \frac{2t^2}{1+2t^2}
# \end{array} \right)
# \times
# \left(\begin{array}{c}
# -\frac{2x}{\sqrt{1+8x^4}}
# \\
# \frac{1-2x^2}{\sqrt{1+8x^4}}
# \\
# \frac{2x^2}{\sqrt{1+8x^4}}
# \end{array} \right)$$

# %% [markdown]
# $$\mathbf{B} =
# \left(\begin{array}{c}
# \frac{2t}{1+2t^2}*\frac{2t^2}{\sqrt{1+8t^4}}-\frac{2t^2}{1+2t^2}*\frac{1-2t^2}{\sqrt{1+8t^4}}
# \\
# \frac{2t^2}{1+2t^2}*-\frac{2t}{\sqrt{1+8t^4}}-\frac{1}{1+2t^2}*\frac{2t^2}{\sqrt{1+8t^4}}
# \\
# \frac{1}{1+2t^2}*\frac{1-2t^2}{\sqrt{1+8t^4}}-\frac{2t}{1+2t^2}* -\frac{2x}{\sqrt{1+8x^4}}
# \end{array} \right)=
# \left(\begin{array}{c}
# \frac{4t^4+4t^3-2t^2}{(1+2t^2)\sqrt{1+8t^4}}
# \\
# -\frac{4t^3+2t^2}{(1+2t^2)\sqrt{1+8t^4}}
# \\
# \frac{1}{\sqrt{1+8t^4}}
# \end{array} \right)$$

# %% [markdown]
# ### Aufgabe 8
#
# Bestimmen Sie in Fortsetzung der vorangegangenen Aufgabe die Torsion $\tau$.

# %% [markdown]
# die Torsion $\tau$, diese ergibt sich aus $\frac{d\mathbf{B}}{ds}=-\tau\mathbf{N} => \tau=-\mathbf{N}*\frac{d\mathbf{B}}{ds}$
# $$\frac{d\mathbf{B}}{ds}=\frac{d\mathbf{B}/dt} {\|d\mathbf{B}/dt\|}$$
#
# $$\frac{d\mathbf{B}}{dt} = \left(\begin{array}{c} \frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)} \\ -\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)}\\ -\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)}  \end{array} \right)$$
#
# $$\|d\mathbf{B}/dt\|=\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}$$
# $$\frac{d\mathbf{B}/dt} {\|d\mathbf{B}/dt\|} = \left(\begin{array}{c} \frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}} \\ -\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}}\\ -\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}}  \end{array} \right)$$
# $$\tau = \left(\begin{array}{c} \frac{2t}{\sqrt{1+8t^4}} \\ -\frac{1-2t^2}{\sqrt{1+8t^4}}\\ -\frac{2t^2}{\sqrt{1+8t^4}}  \end{array} \right)*\left(\begin{array}{c} \frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}} \\ -\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}}\\ -\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)\sqrt{(\frac{-64t^8+128t^7+32t^6+16t^5+8t^4+16t^3+12t^2-4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{-64t^8-64t^7+32t^6+8t^4+12t^2+4t}{\sqrt{1+8t^4}(32t^8+32t^6+12t^4+4t^2+1)})^2+(-\frac{16t^3}{\sqrt{1+8t^4}(1+8t^4)})^2}}  \end{array} \right)$$
