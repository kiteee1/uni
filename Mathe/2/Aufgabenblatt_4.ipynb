# %% [markdown]
# # Aufgabenblatt 4

# %% [markdown]
# ## Eindimensionale Analysis – Grenzwerte

# %% [markdown]
# ### Aufgabe 1
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 4} \frac{x-4}{x^2-x-12}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \lim_{x \rightarrow 4} \frac{x-4}{(x+3)(x-4)}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 4} \frac{1}{(x+3)}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# \lim_{x \rightarrow 4}\frac{1}{4+3}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 4}\frac{1}{7}
# $$

# %% [markdown]
# $$
# \frac{1}{7}
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return (x-4)/(x**2-x-12)
def g(z):
   return (z-4)/(z**2-z-12)
x = np.linspace(-10, -3, 1000)
z = np.linspace(-3, 10, 1000)
plt.ylim(-20, 20)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.plot(z, g(z), color='blue')
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3378980/324610158.py:5: RuntimeWarning: divide by zero encountered in divide
#   return (x-4)/(x**2-x-12)
# /tmp/ipykernel_3378980/324610158.py:7: RuntimeWarning: divide by zero encountered in divide
#   return (z-4)/(z**2-z-12)

# %% [markdown]
# ### Aufgabe 2
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow -1} \frac{x^2+3x+2}{x^4+4x+3}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \lim_{x \rightarrow -1} \frac{(x+2)(x+1)}{(x+1)^2(x^2-2x+3)}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow -1} \frac{(x+2)}{(x+1)(x^2-2x+3)}
# $$

# %% [markdown]
# Da die Funktion nicht für 1 definiert ist, berechnen wir die linken und rechten Grenzen

# %% [markdown]
# $$
# \lim_{x \rightarrow -1^-} \frac{(x+2)}{(x+1)(x^2-2x+3)}
# $$
# $$
# \lim_{x \rightarrow -1^+} \frac{(x+2)}{(x+1)(x^2-2x+3)}
# $$

# %% [markdown]
# $$
# -∞
# $$
# $$
# +∞
# $$

# %% [markdown]
# Da die Grenzwerte für Links- und Rechtshänder unterschiedlich sind, existiert der ursprüngliche Grenzwert nicht

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return (x**2+3*x+2)/(x**4+4*x+3)

x = np.linspace(-3, 3, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(-5, 5)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3378980/3599547681.py:5: RuntimeWarning: invalid value encountered in divide
#   return (x**2+3*x+2)/(x**4+4*x+3)

# %% [markdown]
# ### Aufgabe 3
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 1} \frac{x^4+2x^2-3}{x^2-3x+2}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \lim_{x \rightarrow 1} \frac{(x^2+3)(x^2-1)}{(x-1)(x-2)}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 1} \frac{(x^2+3)(x+1)}{(x-2)}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# \frac{(1^2+3)(1+1)}{(1-2)}
# $$

# %% [markdown]
# $$
# -8
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return (x**4+2*x**2-3)/(x**2-3*x+2)
def g(z):
   return (z**4+2*z**2-3)/(z**2-3*z+2)
x = np.linspace(-10, 2, 1000)
z = np.linspace(2, 10, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.plot(z, g(z), color='blue')
plt.ylim(-20, 60)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3378980/3207171822.py:5: RuntimeWarning: divide by zero encountered in divide
#   return (x**4+2*x**2-3)/(x**2-3*x+2)
# /tmp/ipykernel_3378980/3207171822.py:7: RuntimeWarning: divide by zero encountered in divide
#   return (z**4+2*z**2-3)/(z**2-3*z+2)

# %% [markdown]
# ### Aufgabe 4
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0}x^2\log{x}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \lim_{x \rightarrow 0}\frac{\log{x}}{\frac{1}{x^2}}
# $$

# %% [markdown]
# L’Hospital

# %% [markdown]
# $$
# \lim_{x \rightarrow 0}\frac{\frac{\partial}{\partial x}\log{x}}{\frac{\partial}{\partial x}\frac{1}{x^2}}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0}-\frac{\frac{1}{x}}{\frac{2}{x^3}}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0}-\frac{x^2}{2}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# -\frac{0^2}{2}
# $$

# %% [markdown]
# $$
# 0
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return np.log(x)*x**2

x = np.linspace(-3, 3, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(-5, 5)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3378980/2065986789.py:5: RuntimeWarning: invalid value encountered in log
#   return np.log(x)*x**2

# %% [markdown]
# ### Aufgabe 5
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} \frac{\sin{x}}{x}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# L’Hospital

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} \frac{\cos{x}}{1}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# \frac{\cos{0}}{1}
# $$

# %% [markdown]
# $$
# \frac{1}{1}
# $$

# %% [markdown]
# $$
# 1
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return np.sin(x)/x

x = np.linspace(-30, 30, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(-0.5, 1.5)
plt.grid()
plt.show()

# %% [markdown]
# ### Aufgabe 6
#
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} x^{(x^2)}
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} e^{\log{(x^{(x^2)})}}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} e^{x^2*\log{x}}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} (e^{x^2})^{\log{x}}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# (e^{0^2})^{\log{0}}
# $$

# %% [markdown]
# $$
# 1^{-∞}=\frac{1}{1^∞}=1
# $$

# %% [markdown]
# Antwort: 1

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return x**(x**2)

x = np.linspace(-0.5, 3, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(0, 5)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3437928/4126976938.py:5: RuntimeWarning: invalid value encountered in power
#   return x**(x**2)

# %% [markdown]
# ### Aufgabe 7
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow \infty} (\log{(x+1)}-\log{x})
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# $$
# \log({\lim_{x \rightarrow \infty}(\frac{x+1}{x}}))
# $$

# %% [markdown]
# $$
# \log({\lim_{x \rightarrow \infty}(\frac{x(1+\frac{1}{x})}{x}}))
# $$

# %% [markdown]
# $$
# \log({\lim_{x \rightarrow \infty}(1+\frac{1}{x}}))
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# \log1
# $$

# %% [markdown]
# $$
# 0
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return np.log(x+1)-np.log(x)

x = np.linspace(0, 7, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(0, 3)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3437928/1165855907.py:5: RuntimeWarning: divide by zero encountered in log
#   return np.log(x+1)-np.log(x)

# %% [markdown]
# ### Aufgabe 8
#
# Bestimmen Sie folgenden Grenzwert:
#
# $$
# \lim_{x \rightarrow 0} (\sin{x})^x
# $$
#
# Plotten Sie die Funktion.

# %% [markdown]
# Merken wir:
# $$\lim_{x \rightarrow 0} \sin{x}=\lim_{x \rightarrow 0} x$$
# dann

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} (\sin{x})^x=\lim_{x \rightarrow 0} x^x
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} e^{\log{x^x}}
# $$

# %% [markdown]
# $$
# \lim_{x \rightarrow 0} (e^x)^{\log{x}}
# $$

# %% [markdown]
# Ersetzen wir x

# %% [markdown]
# $$
# (e^0)^{\log{0}}
# $$

# %% [markdown]
# $$
# 1^{-\infty}=\frac{1}{}
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt

def f(x):
   return np.sin(x)**x
x = np.linspace(-20, 20, 1000)
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(x, f(x), color='blue')
plt.ylim(0, 5)
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_3437928/1070678633.py:5: RuntimeWarning: invalid value encountered in power
#   return np.sin(x)**x
