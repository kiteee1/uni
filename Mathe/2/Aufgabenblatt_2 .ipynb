# %% [markdown]
# # Aufgabenblatt 2

# %% [markdown]
# ## Eindimensionale Analysis – Differentialrechnung 2

# %% [markdown]
# ### Aufgabe 1
#
# Berechnen Sie $y'$ durch implizite Differentiation:
#
# a) $$x^2+y^2-r^2=0,r \in \mathbb{R}$$

# %% [markdown]
# $$x^2+y^2=r^2$$

# %% [markdown]
# $$\frac{\partial}{\partial x}(x^2+y^2)=\frac{\partial}{\partial x}r^2$$

# %% [markdown]
# $$\frac{\partial}{\partial x} x^2+ \frac{\partial}{\partial x} y^2=0$$

# %% [markdown]
# $$\frac{\partial}{\partial x} x^2+ \frac{\partial}{\partial x} y^2=0$$

# %% [markdown]
# $$2x + \frac{\partial}{\partial y} y^2 * \frac{\partial y}{\partial x}=0$$

# %% [markdown]
# $$2x + 2y*y'=0$$

# %% [markdown]
# $$y'=-\frac{x}{y}$$

# %% [markdown]
# b) $$e^{xy}=2$$

# %% [markdown]
# $$\frac{\partial}{\partial x}e^{xy}=\frac{\partial}{\partial x}2$$

# %% [markdown]
# $$\frac{\partial}{\partial g}e^{g}*\frac{\partial}{\partial x}(xy)=0$$

# %% [markdown]
# $$e^{g}*(\frac{\partial}{\partial x} xy+x\frac{\partial}{\partial x}y)=0$$

# %% [markdown]
# $$e^{xy}*(y+xy')=0$$

# %% [markdown]
# $$ye^{xy}+e^{xy}xy'=0$$

# %% [markdown]
# $$y'=-\frac{y}{x}$$

# %% [markdown]
# ### Aufgabe 2
#
# Berechnen Sie $y'$ durch implizite Differentiation:
#
# a) $$xy-\log{y}=2$$

# %% [markdown]
# $$\frac{\partial}{\partial x}(xy-\log{y})=\frac{\partial}{\partial x}2$$

# %% [markdown]
# $$\frac{\partial}{\partial x}(xy)-\frac{\partial}{\partial x}(\log{y})=0$$

# %% [markdown]
# $$(\frac{\partial}{\partial x}xy+x\frac{\partial}{\partial x}y)-\frac{\partial}{\partial y}(\log{y})*\frac{\partial y}{\partial x}=0$$

# %% [markdown]
# $$y+xy'-\frac{1}{y}y'=0$$

# %% [markdown]
# $$y'=-\frac{y^2}{(yx-1)}$$

# %% [markdown]
# b) $$yx^2-e^y=0$$

# %% [markdown]
# $$\frac{\partial}{\partial x}(yx^2-e^y)=0$$

# %% [markdown]
# $$\frac{\partial}{\partial x}(yx^2)-\frac{\partial}{\partial x}(e^y)=0$$

# %% [markdown]
# $$(\frac{\partial}{\partial x}yx^2+\frac{\partial}{\partial x}x^2y)-e^yy'=0$$

# %% [markdown]
# $$y'x^2+2xy-e^yy'=0$$

# %% [markdown]
# $$y'=-\frac{2xy}{x^2-e^y}$$

# %% [markdown]
# ### Aufgabe 3
#
# Ermitteln Sie $y'$ durch Logarithmieren und anschließendes Ableiten:
#
# $$y=\sqrt[x]{x}$$

# %% [markdown]
# $$y=x^{\frac{1}{x}}$$

# %% [markdown]
# $$\ln{y}=\ln{x^{\frac{1}{x}}}$$

# %% [markdown]
# $$\ln{y}=\frac{1}{x}\ln{x}$$

# %% [markdown]
# $$\frac{\partial}{\partial x} \ln{y}=\frac{\partial}{\partial x}( \frac{1}{x}\ln{x})$$

# %% [markdown]
# $$\frac{\partial}{\partial y} \ln{y}*\frac{\partial y}{\partial x}=\frac{\partial}{\partial x}\frac{1}{x}\ln{x}+\frac{1}{x}\frac{\partial}{\partial x}\ln{x}$$

# %% [markdown]
# $$\frac{1}{y}*y'=-\frac{1}{x^2}\ln{x}+\frac{1}{x^2}$$

# %% [markdown]
# $$y'=-\frac{y(1-\ln{x})}{x^2}$$

# %% [markdown]
# $$y'=-\frac{(1-\ln{x})x^{\frac{1}{x}}}{x^2}$$

# %% [markdown]
# ### Aufgabe 4
#
# Ermitteln Sie $y'$ durch Logarithmieren und anschließendes Ableiten:
#
#
# $$y=(\sin{x})^{\cos{x}}$$

# %% [markdown]
# $$\ln{y}=\ln{((\sin{x})^{\cos{x}}})$$

# %% [markdown]
# $$\ln{y}=\cos{x}\ln{\sin{x}}$$

# %% [markdown]
# $$\frac{\partial}{\partial x}\ln{y}=\frac{\partial}{\partial x}(\cos{x}\ln{\sin{x}})$$

# %% [markdown]
# $$\frac{\partial}{\partial y}\ln{y}*\frac{\partial y}{\partial x}=\frac{\partial}{\partial x}\cos{x}\ln{\sin{x}}+\cos{x}\frac{\partial}{\partial x}\ln{\sin{x}}$$

# %% [markdown]
# $$\frac{1}{y}y'=-\sin{x}\ln{\sin{x}}+\cos{x}\frac{1}{\sin{x}}\cos{x}$$

# %% [markdown]
# $$y'=\frac{y(cos^{2}{x}-\sin^{2}{x}\ln{\sin{x}})}{\sin{x}}$$

# %% [markdown]
# $$y'=\frac{(cos^{2}{x}-\sin^{2}{x}\ln{\sin{x}})(\sin{x})^{\cos{x}}}{\sin{x}}$$

# %% [markdown]
# ### Aufgabe 5
#
# Ermitteln Sie $y'$ durch Logarithmieren und anschließendes Ableiten:
#
#
# $$y=\sqrt[5]{\frac{(x-1)(x+2)}{x^2-3}}$$

# %% [markdown]
# $$\ln{y}=\frac{1}{5}\ln{{(\frac{(x-1)(x+2)}{x^2-3})}}$$

# %% [markdown]
# $$\frac{\partial}{\partial x}\ln{y}=\frac{\partial}{\partial x}(\frac{1}{5}(\ln{(x-1)}+\ln{(x+2)}-\ln{(x^2-3)}))$$

# %% [markdown]
# $$\frac{1}{y}y'=\frac{1}{5}(\frac{\partial}{\partial x}\ln{(x-1)}+\frac{\partial}{\partial x}\ln{(x+2)}-\frac{\partial}{\partial x}\ln{(x^2-3)})$$

# %% [markdown]
# $$\frac{1}{y}y'=\frac{1}{5}(\frac{(x+2)(x^2-3)+(x-1)(x^2-3)-2x(x-1)(x+2)}{(x-1)(x+2)(x^2-3)})$$

# %% [markdown]
# $$\frac{1}{y}y'=\frac{1}{5}(\frac{x^3-3x+2x^2-6+x^3-3x-x^2+3-2x^3-4x^2+2x^2+4x}{x^4-3x^2+x^3-3x-2x^2+6})$$

# %% [markdown]
# $$\frac{1}{y}y'=-\frac{x^2+2x+3}{5x^4+5x^3-25x^2-15x+30}$$

# %% [markdown]
# $$y'=-\frac{x^2+2x+3}{5x^4+5x^3-25x^2-15x+30}*y$$

# %% [markdown]
# $$y'=-\frac{x^2+2x+3}{5x^4+5x^3-25x^2-15x+30}*\sqrt[5]{\frac{(x-1)(x+2)}{x^2-3}}$$

# %% [markdown]
# ### Aufgabe 6
#
#
# Berechnen Sie im Punkt $P_{0}(1|y_{0})$ die Krümmung der Kurve
# $y=x^3$. Hinweis: die Krümmung $\kappa$ einer Kurve ist definiert
# als $\kappa=\frac{y''}{(1+y'^2)^{3/2}}$.

# %% [markdown]
# $$y'=3x^2$$
# $$y''=6x$$

# %% [markdown]
# $$\kappa=\frac{6x}{(1+(3x^2)^2)^{3/2}}$$

# %% [markdown]
# $$\kappa=\frac{6x}{(1+(9x^4)^{3/2}}$$

# %% [markdown]
# $$\kappa=\frac{6*1}{(1+(9*1^4)^{3/2}}$$

# %% [markdown]
# $$\kappa=\frac{6}{10^{3/2}}$$

# %% [markdown]
# $$\kappa\approx0.189737$$

# %% [markdown]
# ### Aufgabe 7
#
# Bestimmen Sie den Krümmungsradius und den Krümmungsmittelpunkt im
# Punkt $P_{0}(1|y_{0})$ der Kurve $y=\sqrt{x}$. Hinweis: der
# Krümmungsradius $\rho=\frac{1}{\kappa}$, die Koordinaten des
# Krümmungsmittelpunktes $M(x_{M}|y_{M}):
# x_{M}=x-\frac{y'}{y''}(1+y'^2), y_{M}=y+\frac{1}{y''}(1+y'^2)$. Plotten Sie die Kurve $y$ und den Krümmungskreis.

# %% [markdown]
# $$y'=\frac{1}{2\sqrt{x}}$$
# $$y''=-\frac{1}{4x\sqrt{x}}$$
# $$\kappa=\frac{-\frac{1}{4x\sqrt{x}}}{(1+(\frac{1}{2\sqrt{x}})^2)^{3/2}}$$

# %% [markdown]
# $$\rho=\frac{(1+(\frac{1}{2\sqrt{x}})^2)^{3/2}}{-\frac{1}{4x\sqrt{x}}}$$

# %% [markdown]
# $$\rho=\frac{(1+(\frac{1}{2\sqrt{1}})^2)^{3/2}}{-\frac{1}{4*1\sqrt{1}}}$$

# %% [markdown]
# $$\rho=-\frac{5\sqrt{5}}{2}\approx-5.59017$$
# Das negative Vorzeichen besagt, dass die Krümmung in die entgegengesetzte Richtung zum Normalenvektor verläuft bzw. dass die Funktion in diesem Punkt konkav ist.

# %% [markdown]
# $$x_{M}=x-\frac{\frac{1}{2\sqrt{x}}}{-\frac{1}{4x\sqrt{x}}}(1+(\frac{1}{2\sqrt{x}})^2)$$

# %% [markdown]
# $$x_{M}=1-\frac{\frac{1}{2\sqrt{1}}}{-\frac{1}{4*1\sqrt{1}}}(1+(\frac{1}{2\sqrt{1}})^2)$$

# %% [markdown]
# $$x_{M}=1-\frac{\frac{1}{2\sqrt{1}}}{-\frac{1}{4*1\sqrt{1}}}(1+(\frac{1}{2\sqrt{1}})^2)$$

# %% [markdown]
# $$x_{M}=\frac{7}{2}$$

# %% [markdown]
# $$y_{M}=\sqrt{x}+\frac{1}{-\frac{1}{4x\sqrt{x}}}(1+(\frac{1}{2\sqrt{x}})^2)$$

# %% [markdown]
# $$y_{M}=\sqrt{1}+\frac{1}{-\frac{1}{4*1\sqrt{1}}}(1+(\frac{1}{2\sqrt{1}})^2)$$

# %% [markdown]
# $$y_{M}=-4$$

# %% [markdown]
# Gleichung des Krümmungskreises: $(x-\frac{7}{2})^2+(y+4)^2=\frac{125}{4}$

# %%
# %config InlineBackend.figure_formats = ['svg']
import numpy as np
import matplotlib.pyplot as plt

def f(x):
   return np.sqrt(x)
    
x = np.linspace(-3, 10, 1000)
y = np.linspace(-10, 4, 1000)
X, Y = np.meshgrid(x,y)
C = (X-3.5)**2 + (Y+4)**2 - 31.25
plt.contour(X,Y,C,[0])
plt.plot(x, f(x), color='blue')
plt.axhline()
plt.axvline()
plt.axhline(color='black', lw=0.5)
plt.axvline(color='black', lw=0.5)
plt.plot(3.5,-4,'ro', label='— Krümmungsmittelpunkt ')
plt.plot([1,3.5],[1,-4])
plt.plot(x,(0.5*x)+0.5)

plt.gca().set_aspect('equal')
plt.grid()
plt.show()
# Out:
# /tmp/ipykernel_605059/489468296.py:6: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x)

# %% [markdown]
# ### Aufgabe 8
#
# Wo ist die Kurve $y=\log{x}$ am stärksten gekrümmt? Hinweis:
# Bestimmen Sie die Krümmung $\kappa$, substituieren Sie $z=1/x^2$ und
# finden Sie das Maximum für $\kappa^2$.

# %% [markdown]
# $$y'=\frac{1}{x}$$
# $$y''=-\frac{1}{x^2}$$
# $$\kappa=\frac{y''}{(1+y'^2)^{3/2}}$$
# $$\kappa=\frac{-\frac{1}{x^2}}{(1+(\frac{1}{x})^2)^{3/2}}$$

# %% [markdown]
# $$\kappa=\frac{-z}{(1+z)^{3/2}}$$

# %% [markdown]
# $$\kappa^2=\frac{z^2}{(1+z)^3}$$

# %% [markdown]
# Lass $\kappa^2=t$, dann:

# %% [markdown]
# $$t'=\frac{(z^2)'(1+z)^3-z^2((1+z)^3)'}{((1+z)^3)^2}$$

# %% [markdown]
# $$t'=\frac{2z(1+z)^3-3z^2((1+z)^2)}{((1+z)^3)^2}$$

# %% [markdown]
# $$t'=\frac{(1+z)^2(2z(1+z)-3z^2)}{(1+z)^6}$$

# %% [markdown]
# $$t'=\frac{(2z(1+z)+3z^2)}{(1+z)^4}$$

# %% [markdown]
# $$t'=\frac{2z-z^2}{(1+z)^4}$$

# %% [markdown]
# <table style="text-align: center">
# <tr>
#     <td><font size="3">$(-∞;-1)$</font></td>
#     <td><font size="3">$-1$</font></td>
#     <td><font size="3">$(-1;0)$</font></td>
#     <td><font size="3">$0$</font></td>
#     <td><font size="3">$(0;2)$</font></td>
#     <td><font size="3">$2$</font></td>
#     <td><font size="3">$(2;+∞)$</font></td>
# </tr>
#
# <tr>
#     <td><font size="3">$t'<0$</font></td>
#     <td><font size="3">Unterbrechung</font></td>
#     <td><font size="3">$t'<0$</font></td>
#     <td><font size="3">$t'=0$</font></td>
#     <td><font size="3">$t'>0$</font></td>
#     <td><font size="3">$t'=0$</font></td>
#     <td><font size="3">$t'<0$</font></td>
# </tr>
#
# <tr>
#     <td><font size="3">Funktion fällt</font></td>
#     <td><font size="3">Unterbrechung</font></td>
#     <td><font size="3">Funktion fällt</font></td>
#     <td><font size="3">min</font></td>
#     <td><font size="3">Funktion steigt</font></td>
#     <td><font size="3">max</font></td>
#     <td><font size="3">Funktion fällt</font></td>
# </tr>
#
# </table>

# %% [markdown]
# An Punkt 2 gibt es ein lokales Maximum der Funktion t, daher ist die Krümmung an diesem Punkt maximal
