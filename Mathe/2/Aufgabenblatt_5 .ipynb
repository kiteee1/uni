# %% [markdown]
# # Aufgabenblatt 5

# %% [markdown]
# ## Eindimensionale Analysis – Taylorreihen

# %% [markdown]
# ### Aufgabe 1
#
# Entwickeln Sie die Funktion $f(x)=e^{\cos(x)-1}$ in eine Taylorreihe
# um den Nullpunkt bis zum Glied 2. Ordnung. Verwenden Sie SymPy, um
# Ihr Ergebnis zu überprüfen und weitere Glieder bis zum Glied 10.
# Ordnung zu bestimmen. Stellen Sie die Funktion sowie die
# fortschreitende Approximation durch zusätzliche Glieder der
# Taylorreihe bis zum Glied 10. Ordnung auch grafisch dar. Bestimmen
# Sie mittels ihrer Taylorreihen unter Verwendung von SymPy für $x=0.15$ die fortschreitende Approximation für den Funktionswert bis zum Glied 10. Ordnung.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=2; a=0$$
# $$f'(x)=-e^{\cos{(x)}-1}\sin{(x)}$$
# $$f''(x)=e^{\cos{(x)}-1}(\sin^2{(x)}-\cos{(x)})$$
# $$T_{2}(f,x,0)=e^{\cos(0)-1}-e^{\cos{(0)}-1}\sin{(0)}x+\frac{e^{\cos{(0)}-1}(\sin^2{(0)}-\cos{(0)})}{2!}(x-0)^2$$
# $$T_{2}(f,x,0)=1-\frac{x^2}{2}$$

# %%
from sympy import diff, symbols, factorial, exp, cos, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = exp(cos(x)-1)
n = 2
a = 0
X = 0.15
print("n = 2")
t = taylor(f, x, n, a)
pretty_print(t)
print("While x =",X,", T", n, "(f , x,",a,") = ", t.evalf(subs={x:X}))
print("n = 10")
n = 10 
t = taylor(f, x, n, a)
pretty_print(t)
print("While x =",X,", T", n, "(f , x,",a,") = ", t.evalf(subs={x:X}))
print("Real value: ", f.evalf(subs={x:X}))
print("Plot:")
p = plot(f, taylor(f, x, 2, a), taylor(f, x, 10, a), xlim=[-10, 10], ylim=[-10,1.5], show=False)
p.show()
# Out:
# n = 2
#      2
#     x
# 1 - ──
#     2
# While x = 0.15 , T 2 (f , x, 0 ) =  0.988750000000000
# n = 10
#         10        8       6    4    2
#   1639⋅x     379⋅x    31⋅x    x    x
# - ──────── + ────── - ───── + ── - ── + 1
#    907200    40320     720    6    2
# While x = 0.15 , T 10 (f , x, 0 ) =  0.988833886968961
# Real value:  0.988833886969001
# Plot:

# %% [markdown]
# ### Aufgabe 2
#
# Entwickeln Sie die Funktion $f(x)=\tan{x}$ in eine Taylorreihe
# um den Nullpunkt bis zum Glied 3. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=3; a=0$$
# $$f'(x)=\frac{1}{\cos^2{x}}$$
# $$f''(x)=\frac{2\sin{x}}{\cos^3{x}}$$
# $$f'''(x)=\frac{2+4\sin^2{x}}{\cos^4{x}}$$
# $$T_{3}(f,x,0)=\tan{0}+\frac{1}{\cos^2{0}}x+\frac{\frac{2\sin{0}}{\cos^3{0}}}{2!}x^2+\frac{\frac{2+4\sin^2{0}}{\cos^4{0}}}{3!}x^3$$
# $$T_{3}(f,x,0)=\frac{3x+x^3}{3}$$

# %%
from sympy import diff, symbols, factorial, tan, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = tan(x)

p = plot(f, taylor(f, x, 3, 0), xlim=[-10, 10], ylim=[-5,5], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 3
#
# Entwickeln Sie die Funktion $f(x)=1/\cos{x}$ in eine Taylorreihe
# um den Nullpunkt bis zum Glied 2. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=2; a=0$$
# $$f'(x)=\frac{\sin{x}}{\cos^2{x}}$$
# $$f''(x)=\frac{1+\sin^2{x}}{\cos^3{x}}$$
# $$T_{2}(f,x,0)=\frac{1}{\cos{0}}+\frac{\sin{0}}{\cos^2{0}}x+\frac{\frac{1+\sin^2{0}}{\cos^3{0}}}{2!}x^2$$
# $$T_{2}(f,x,0)=\frac{2+x^2}{2}$$

# %%
from sympy import diff, symbols, factorial, cos, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = 1/cos(x)

a = 0

p = plot(f, taylor(f, x, 2, a), xlim=[-10, 10], ylim=[-5,5], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 4
#
# Entwickeln Sie die Funktion $f(x)=\arcsin{x}$ in eine Taylorreihe
# um den Nullpunkt bis zum Glied 3. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=3; a=0$$
# $$f'(x)=\frac{1}{\sqrt{1+x^2}}$$
# $$f''(x)=-\frac{x}{\sqrt{1+x^2}(1+x^2)}$$
# $$f'''(x)=\frac{2x^2+1}{\sqrt{1+x^2}(1+x^2)^2}$$
# $$T_{3}(f,x,0)=\arcsin{0}+\frac{1}{\sqrt{1+0^2}}x-\frac{\frac{0}{\sqrt{1+0^2}(1+0^2)}}{2!}x^2+\frac{\frac{2*0^2+1}{\sqrt{1+0^2}(1+0^2)^2}}{3!}x^3$$
# $$T_{3}(f,x,0)=x+\frac{1}{6}x^3$$

# %%
from sympy import diff, symbols, factorial, asin, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = asin(x)

a = 0

p = plot(f, taylor(f, x, 3, a), xlim=[-2, 2], ylim=[-2,2], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 5
#
# Entwickeln Sie die Funktion $f(x)=\ln{\frac{1+x}{1-x}}$ in eine Taylorreihe um den Nullpunkt bis zum Glied 3. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=3; a=0$$
# $$f'(x)=\frac{2}{1-x^2}$$
# $$f''(x)=\frac{4x}{(1-x^2)^2}$$
# $$f'''(x)=\frac{4+12x^2}{(1-x^2)^3}$$
# $$T_{3}(f,x,0)=\ln{\frac{1+0}{1-0}}+\frac{2}{1-0^2}x+\frac{\frac{4*0}{(1-0^2)^2}}{2!}x^2+\frac{\frac{4+12*0^2}{(1-0^2)^3}}{3!}x^3$$
# $$T_{3}(f,x,0)=\frac{6x+2x^3}{3}$$

# %%
from sympy import diff, symbols, factorial, log, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = log((1+x)/(1-x))

a = 0

p = plot(f, taylor(f, x, 3, a), xlim=[-2, 2], ylim=[-6,6], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 6
#
#
# Entwickeln Sie die Funktion $f(x)=\arctan{\frac{x}{1+x}}$ in eine Taylorreihe um den Nullpunkt bis zum Glied 3. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=3; a=0$$
# $$f'(x)=\frac{1}{2x^2+2x+1}$$
# $$f''(x)=-\frac{4x+2}{(2x^2+2x+1)^2}$$
# $$f'''(x)=\frac{24x^2+24x+4}{(2x^2+2x+11)^3}$$
# $$T_{3}(f,x,0)=\arctan{\frac{0}{1+0}}+\frac{1}{2*0^2+2*0+1}x-\frac{\frac{4*0+2}{(2*0^2+2*0+1)^2}}{2!}x^2+\frac{\frac{24*0^2+24*0+4}{(2*0^2+2*0+1)^3}}{3!}x^3$$
# $$T_{3}(f,x,0)=\frac{2x^3}{3}-x^2+x$$

# %%
from sympy import diff, symbols, factorial, atan, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = atan(x/(1+x))
a = 0

p = plot(f, taylor(f, x, 3, a), xlim=[-2, 2], ylim=[-6,6], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 7
#
# Entwickeln Sie die Funktion $f(x)=e^{\sin(x)}$ in eine Taylorreihe
# um den Nullpunkt bis zum Glied 4. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=4; a=0$$
# $$f'(x)=e^{\sin(x)}*\cos{x}$$
# $$f''(x)=e^{\sin(x)}*\cos^2{x}-e^{\sin(x)}*\sin{x}$$
# $$f'''(x)=-e^{\sin(x)}*\cos{x}\sin^2{x}-\frac{3e^{\sin(x)}*\sin{2x}}{2}$$
# $$f''''(x)=\frac{1}{2}e^{\sin(x)}(2\sin^3{x}-6\cos(2x)-2(\sin{x}+2)\sin{x}\cos^2{x}-3\sin{2x}\cos{x})$$
# $$T_{4}(f,x,0)=e^{\sin(0)}+e^{\sin(0)}*\cos{0}x+\frac{e^{\sin(0)}*\cos^2{0}-e^{\sin(0)}*\sin{0}}{2!}x^2+\frac{-e^{\sin(0)}*\cos{0}\sin^2{0}-\frac{3e^{\sin(0)}*\sin{2*0}}{2}}{3!}x^3+\frac{\frac{1}{2}e^{\sin(0)}(2\sin^3{0}-6\cos(2*0)-2(\sin{0}+2)\sin{0}\cos^2{0}-3\sin{2*0}\cos{0})}{4!}x^4$$
# $$T_{4}(f,x,0)=1+x+\frac{x^2}{2}-\frac{x^4}{8}$$

# %%
from sympy import diff, symbols, factorial, exp, sin, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = exp(sin(x))
a = 0

p = plot(f, taylor(f, x, 4, a), xlim=[-2, 2], ylim=[-6,6], show=False)
p.show()

# %% [markdown]
# ### Aufgabe 8
#
# Entwickeln Sie die Funktion $f(x)=\frac{1-\cos{x}}{\ln(x+1)}$ in eine Taylorreihe um den Nullpunkt bis zum Glied 1. Ordnung.
#
# Plotten Sie die Funktion und die Taylorreihe.

# %% [markdown]
# $$T_{n}(f,x,a)=\sum_{k=0}^n \frac{f^{(k)}(a)}{k!}(x-a)^k$$

# %% [markdown]
# $$n=1; a=0$$
# $$f'(x)=\frac{(x+1)\sin{x}\ln{(x+1)}-1+\cos{x}}{x\ln^2{(x+1)}+\ln^2{(x+1)}}$$
# $$T_{1}(f,x,0)=\frac{1-\cos{0}}{\ln(0+1)}+\frac{(0+1)\sin{0}\ln{(0+1)}-1+\cos{0}}{0\ln^2{(0+1)}+\ln^2{(0+1)}}x$$
# f'(0) ist undefiniert, d.h finden wir $\lim_{x\to0} f'(x)$
# $$ \lim_{x\to0}(\frac{(x+1)\sin{x}\ln{(x+1)}-1+\cos{x}}{x\ln^2{(x+1)}+\ln^2{(x+1)}})$$
# L'Hopital
# $$\lim_{x\to0}(\frac{((x+1)\sin{x}\ln{(x+1)}-1+\cos{x})'}{(x\ln^2{(x+1)}+\ln^2{(x+1)})'})$$
# $$\lim_{x\to0}(\frac{(\sin{x}+(x+1)\cos{x})\ln{(x+1)}}{\ln^2{(x+1)}+2\ln{(x+1)}})$$
# $$\lim_{x\to0}(\frac{(\sin{x}+(x+1)\cos{x})}{\ln{(x+1)}+2})$$
# $$\frac{(\sin{0}+(0+1)\cos{0})}{\ln{(0+1)}+2}=\frac{1}{2}$$
# $$T_{1}(f,x,0)=\frac{x}{2}$$

# %%
from sympy import diff, symbols, factorial, log, cos, pretty_print, solve
from sympy.abc import r
from sympy.plotting import plot

def taylor(f, x, n, a):
    result = f.subs(x, a)
    for i in range(1, n+1):
        result += diff(f, x, i).subs(x, a)*(x-a)**i / factorial(i)
    return result

x = symbols("x")

f = (1-cos(x))/(log(x+1))
a = 0.0000000001

p = plot(f, taylor(f, x, 1, a), xlim=[-10, 10], ylim=[-4,4], show=False)
p.show()
